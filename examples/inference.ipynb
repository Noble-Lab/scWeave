# %% [markdown]
# # scWeave — Inference (placeholder)
#
# **Coming soon.** This notebook will walk through running a trained scWeave
# model end to end. Planned contents:
#
# 1. Load a trained model with `scWeave.load(checkpoint_path)`.
# 2. Prepare RNA inputs with `prepare_rna` + `load_gene_names`.
# 3. Prepare Hi-C inputs (HiCFoundation embeddings) — *coming soon*.
# 4. Predict Hi-C from RNA (`predict_hic_from_rna`).
# 5. Predict RNA from Hi-C (`predict_rna_from_hic`).
# 6. Match cells across modalities (`match`).
# 7. Evaluate predictions (SCC, HiCRep, AUROC).

# %%
# from scweave import scWeave, prepare_rna, load_gene_names
#
# model = scWeave.load("scweave.ckpt")
# rna = prepare_rna("expression.h5ad", load_gene_names("mouse"))
# hic = ...   # HiCFoundation embeddings (coming soon)
#
# hic_pred = model.predict_hic_from_rna(rna)
# rna_pred = model.predict_rna_from_hic(hic)
# similarity, matches = model.match(rna, hic, direction="rna_to_hic")
