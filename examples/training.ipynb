# %% [markdown]
# # scWeave — Training (placeholder)
#
# **Coming soon.** This notebook will walk through training scWeave from scratch
# (reproducing the Figure 2 mouse model). Planned contents:
#
# 1. Prepare datasets from source (raw GEO data -> AnnData + HiCFoundation
#    embeddings + contact matrices) — *coming soon*.
# 2. Build the train/val/test splits with `prepare_dataset`.
# 3. Build DataLoaders over `MultimodalDataset`.
# 4. Train the model with `train_translator`.
# 5. Load the resulting checkpoint with `scWeave.load` for inference.

# %%
# from scweave.training import prepare_dataset, MultimodalDataset, train_translator
#
# datasets = ["HiRES_embryo", "HiRES_brain", "GAGEseq_brain", "CHARM_brain"]
# prepare_dataset(
#     adatas=[f"{d}/rna.h5ad" for d in datasets],
#     embeddings=[f"{d}/embeddings.npy" for d in datasets],
#     matrices=[f"{d}/matrices.npy" for d in datasets],
#     ids=[f"{d}/ids.npy" for d in datasets],
#     names=datasets,
#     gene_names="mouse",
#     out_dir="data/prepared",
# )
#
# train = MultimodalDataset("data/prepared/training_set", split="train")
# val = MultimodalDataset("data/prepared/training_set", split="val")
# result = train_translator(train_loader, val_loader, rna_dim=train.n_genes,
#                           hic_num_chr=train.embeddings_shape[0])
